# %%
# 사용할 라이브러리

import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings(action='ignore')

import datetime 
import importlib
import json
from datetime import datetime

import webbrowser

# !apt install chromium-chromedriver
# !pip install selenium

from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

from bs4 import BeautifulSoup
import numpy as np
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (85.0.4183.121-0ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Requirement already satisfied: selenium in /usr/local/lib/python3.6/dist-packages (3.141.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium) (1.24.3)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
driver = webdriver.Chrome('chromedriver',options=options)
driver.get('https://icare.seoul.go.kr/icare/user/careResve/BD_selectChilCareResveList.do')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install kora -q
from kora.selenium import wd
# Out:
#      |████████████████████████████████| 40kB 1.5MB/s

# %%
print(driver.page_source)
# Out:
# <html lang="ko" class=""><head><script type="text/javascript" src="https://weblog2.eseoul.go.kr/event/?ra=2FVJX0RGNC3DXQV2600BRNUGQ2OPEV14&amp;service_id=icare.seoul.go.kr&amp;pc_id=16018240763466989002723&amp;session_id=&amp;screen=800x600&amp;language=en-US&amp;mode=&amp;referrer=&amp;unique_info=%5B%7B%22code%22%3A%22PLUG%22%2C%20%22hsCode%22%3A%22d41d8cd98f00b204e9800998ecf8427e%22%7D%2C%20%7B%22code%22%3A%22UAGT%22%2C%20%22hsCode%22%3A%22853048be9d8e84d895665845ad017125%22%7D%2C%20%7B%22code%22%3A%22SCRE%22%2C%20%22hsCode%22%3A%22572cda553fa9ac8d225f93d1bae76ab8%22%7D%5D&amp;e_url=https%3A%2F%2Ficare.seoul.go.kr%2Ficare%2Fuser%2FcareResve%2FBD_selectChilCareResveList.do&amp;e_title=%0A%09%0A%09%09%0A%09%09%EC%9A%B0%EB%A6%AC%EB%8F%99%EB%84%A4%ED%82%A4%EC%9B%80%EC%84%BC%ED%84%B0%20%EC%98%88%EC%95%BD%20%3A%20HOME%20%26gt%3B%20%EC%9A%B0%EB%A6%AC%EB%8F%99%EB%84%A4%ED%82%A4%EC%9B%80%EC%84%BC%ED%84%B0%20%EC%98%88%EC%95%BD%20%26gt%3B%20%EC%9A%B0%EB%A6%AC%EB%8F%99%EB%84%A4%ED%82%A4%EC%9B%80%EC%84%BC%ED%84%B0%20%EC%98%88%EC%95%BD%0A%09%0A&amp;e_type=pageview&amp;END" async="" charset="UTF-8"></script>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <link rel="SHORTCUT ICON" href="/icare/resources/idolbom/img/main/favicon.ico">
#
# <title>
#
#
# 		우리동네키움센터 예약 : HOME &gt; 우리동네키움센터 예약 &gt; 우리동네키움센터 예약
#
# </title>
#
# <!-- customize -->
# <link rel="stylesheet" type="text/css" href="/icare/resources/openworks4/css/openworks4-custom.css">
# <link rel="stylesheet" type="text/css" href="/icare/resources/libs/jquery-ui-1.11.3.custom/jquery-ui.min.css">
#     <script type="text/javascript" src="//weblog.eseoul.go.kr/wlo/js/AutoEvent.js?202094" async="" charset="utf-8"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" src="//weblog.eseoul.go.kr/wlo/js/seetoc.js?202094" async="" charset="utf-8"></script><script type="text/javascript" src="//weblog.eseoul.go.kr/wlo/js/wl6.js?202094" async="" charset="utf-8"></script><script type="text/javascript">var CTX_PATH="";</script>
# <!-- jquery core -->
# <!-- <script type="text/javascript" src="/icare/resources/libs/jquery/jquery-1.11.2.min.js"></script> -->
# <script type="text/javascript" src="/icare/resources/idolbom/js/lib/jquery-1.12.4.min.js"></script>
# <script type="text/javascript" src="/icare/resources/libs/jquery-ui-1.11.3.custom/jquery-ui.min.js"></script>
#
#
# <!-- 설정 동기화 -->
# <script type="text/javascript" src="/icare/component/js/ND_globalConfig.do"></script>
# <script type="text/javascript" src="/icare/component/js/ND_massageConfig.do"></script>
#
# <!-- Openworks 공통 메소드 -->
# <script type="text/javascript" src="/icare/resources/openworks4/js/openworks.global.js"></script>
# <script type="text/javascript" src="/icare/resources/openworks4/js/openworks.message.js"></script>
# <script type="text/javascript" src="/icare/resources/openworks4/js/openworks.initialize.js"></script>
#
#
# <link rel="stylesheet" type="text/css" href="/icare/resources/idolbom/css/reset.css">
# <link rel="stylesheet" type="text/css" href="/icare/resources/idolbom/css/layout.css">
# <link rel="stylesheet" type="text/css" href="/icare/resources/idolbom/css/layout_media.css">
# <link rel="stylesheet" type="text/css" href="/icare/resources/idolbom/css/sub_content.css">
# <link rel="stylesheet" type="text/css" href="/icare/resources/idolbom/css/sub_content_media.css">
# <script src="/icare/resources/idolbom/js/lib/bxslider.min.js"></script>
# <script src="/icare/resources/idolbom/js/layout.js"></script>
# <script src="/icare/resources/idolbom/js/sub.js"></script>
#
# <link rel="stylesheet" type="text/css" href="/icare/resources/idolbom/css/add_200221.css"><!-- 20200221 팝업 css -->
# <link rel="stylesheet" type="text/css" href="/icare/resources/idolbom/css/add_sns.css"><!-- 20200422 sns 추가 css -->
# <script type="text/javascript" src="https://www.seoul.go.kr/seoulgnb/gnb.js"></script>
#
# <script type="text/javascript" src="/icare/resources/openworks4/js/openworks.form.js"></script>
#     <script type="text/javascript" src="/icare/resources/openworks4/js/openworks.ui.js"></script>
#     <link rel="stylesheet" type="text/css" href="/icare/resources/libs/fancybox-2.1.5/css/jquery.fancybox.css">
#     <script type="text/javascript" src="/icare/resources/libs/fancybox-2.1.5/js/jquery.fancybox.js"></script>
# <script type="text/javascript" src="/icare/resources/openworks4/js/openworks.modal.js"></script>
#
# <script type="text/javascript" src="/icare/resources/libs/form-3.51.0/jquery.form.js"></script>
#
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-154136673-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-154136673-1');
# </script>
# <script>
# /* 초기화 */
# $(document).ready(function() {
# 	window.onload = function() {
# 		Yjs.Gnb.init("G210", "seoul-common-gnb");
# 	};
# });
#
# /* 개발 로그인 */
# /* var devLoginPop = function() {
# 	$().opmodal({
# 		href : "/icare/user/mypage/PD_devLoginForm.do",
# 		width : 500
# 	});
# } */
# </script>
#
#
# <script type="text/javascript">
#     var CTX_PATH="";
# </script>
#
#
#
#
# 	<script type="text/javascript" src="/icare/resources/openworks4/js/openworks.form.js"></script>
#
# 	<!-- 지도 기능 -->
# 	<script type="text/javascript" src="/icare/resources/user/common/seoulMap/js/seoulMap.js"></script>
# 	<!-- 서울맵 지도 SDK -->
# 	<link rel="stylesheet" type="text/css" href="//map.seoul.go.kr/smgis/apps/mapsvr.do?cmd=gisMapCss">
# 	<script type="text/javascript" src="//map.seoul.go.kr/smgis/apps/mapsvr.do?cmd=gisMapJs&amp;key=593bb28f00a84028ab843b6553502818"></script>
# 	<!-- //서울맵 지도 SDK -->
#
# 	<script type="text/javascript">
# 		//<![CDATA[
#
# 		/* 공통 초기화 기능 */
# 		$(document).ready(function() {
#
# 			$("#q_searchVal").keypress(function (e) {
# 				if (e.which == 13){
# 					searchVal();
# 				}
# 			});
#
# 			firstInit = 0;
#
# 			// 시설지도
# 			$("#popupMap").click(function () {
# 				$(".area_popup").show();
# 				$(".area_popup").attr("tabindex","0");
# 				$(".area_popup").focus();
# 				$("#mask").show();
# 				if(firstInit == 0){
# 					mapInit();
# 				}
# 				var firstChk = $("#q_map_atdrcCode").val();
# 				if(firstChk != '' || firstChk != null || firstChk != undefined){
# 					mapSetting(firstChk);
# 				}else{
# 					mapSetting();
# 				}
# 				firstInit = 1;
# 				$("#popupMap").attr("data-focus","on_popupMap");
# 				$("#p_area_all").focus();
# 				return false;
# 			});
#
# 			//지역 전체 선택
# 			$("#area_all").click(function(){
# 				var checked = $(this).prop("checked");
# 				if(checked) {
# 					$("input:checkbox[id^=area_]").prop("checked", true);
# 				} else {
# 					$("input:checkbox[id^=area_]").prop("checked", false);
# 				}
# 			});
#
# 			// 지역 전체 키보드 선택
# 			$("#area_all").keyup(function(){
# 				var checked = $(this).prop("checked");
# 				if(window.event.keyCode == 13){
# 					if(checked) {
# 						$("input:checkbox[id^=area_]").prop("checked", true);
# 					} else {
# 						$("input:checkbox[id^=area_]").prop("checked", false);
# 					}
# 				}
# 			});
#
# 			//지역 일부 선택
# 			$("input:checkbox[id^=area_]").click(function(){
# 				var num = $("input:checkbox[id^=area_]").not("#area_all").length;
# 				var num2 = $("input:checkbox[id^=area_]:checked").not("#area_all").length;
# 				if(num == num2){
# 					$("input:checkbox[id=area_all]").prop("checked", true);
# 				}else{
# 					$("input:checkbox[id=area_all]").prop("checked", false);
# 				}
# 			});
#
# 			//지역 일부 키보드 선택
# 			$("input:checkbox[id^=area_]").keyup(function(){
# 				var num = $("input:checkbox[id^=area_]").not("#area_all").length;
# 				var num2 = $("input:checkbox[id^=area_]:checked").not("#area_all").length;
# 				if(window.event.keyCode == 13){
# 					if(num == num2){
# 						$("input:checkbox[id=area_all]").prop("checked", true);
# 					}else{
# 						$("input:checkbox[id=area_all]").prop("checked", false);
# 					}
# 				}
# 			});
#
# 			// 시설지도 닫기버튼 클릭 후 포커스 이동
# 			$("#popupMapClose").click(function(){
# 				$("input[data-focus=on_popupMap]").focus(); // 표시해둔 곳으로 초점 이동
# 				window.setTimeout(function(){
# 					$("input[data-focus=on_popupMap]").removeAttr("data-focus");
# 				},500); // 역할을 다하고 필요없어진 표시 삭제
# 				return false;
# 			})
#
# 			// 예약현황 닫기버튼 클릭 후 포커스 이동
# 			$(".popupClose").click(function () {
# 				$(".reserv_popup").hide();
# 				$(".remove").empty();
# 				$(".day_reserv_table tbody").html('<tr><td style="text-align:center;">이용 기간을 선택해주세요.</td></tr>');
# 				$("#mask").hide();
# 				var index = $(".index").val();
# 				$("a[data-focus=on_popup_"+index+"]").focus(); // 표시해둔 곳으로 초점 이동
# 				window.setTimeout(function(){
# 					$("a[data-focus=on_popup_"+index+"]").removeAttr("data-focus");
# 				},500); // 역할을 다하고 필요없어진 표시 삭제
# 				return false;
# 			});
#
# 		});
#
# 		var resvePopup = function(index, fcltyId, satOperAt, fcltyNm, useAt, operStpgeResn, operYear){
#
# 			if(useAt == "P"){	// 운영정보 준비중
# 				alert(operStpgeResn);
# 				return;
# 			}
#
# 			$("#q_fcltyId").val(fcltyId);
# 			$("#q_satOperAt").val(satOperAt);
# 			$("#q_operYear").val(operYear);
# 			$(".index").val(index);
#
# 			$("#fcltyName").text(fcltyNm+" 예약 현황");
# 			$("#statusUl").show();
# 			$("#allReservName").attr("href", "BD_insertChilCareResveForm.do?q_fclty=1001&q_fcltyId="+fcltyId+"&q_resveStleCode=1001");
# 			$("#timeReservName").attr("href", "BD_insertChilCareResveForm.do?q_fclty=1002&q_fcltyId="+fcltyId+"&q_resveStleCode=1002");
# 			$("#onceReservName").attr("href", "BD_insertChilCareResveForm.do?q_fclty=1003&q_fcltyId="+fcltyId+"&q_resveStleCode=1003");
#
# 			$(".popup_wrap > div").hide();
# 			$(".tab_popup01").show();
# 			$(".tab li").removeClass("tab_on");
# 			$(".tab_btn01").addClass("tab_on");
# 			$(".tab_btn02").removeClass("tab_on");
# 			resveOrdtm();
# 			var el = $("#btnPopup_"+index);
# 			var target = $(".state_p");
# 			target.show();
# 			el.attr("data-focus","on_popup_"+index);
# 			$("#mask").show();
# 			target.attr("tabindex","0");
# 			target.focus();
# 			return false;
# 		};
#
# 		// 일시돌봄 전용 팝업
# 		var resveOncePopup = function(index, fcltyId, satOperAt, fcltyNm, useAt, operStpgeResn, operYear){
#
# 			if(useAt == "P"){	// 운영정보 준비중
# 				alert(operStpgeResn);
# 				return;
# 			}
#
# 			$("#q_fcltyId").val(fcltyId);
# 			$("#q_satOperAt").val(satOperAt);
# 			$("#q_operYear").val(operYear);
# 			$(".index").val(index);
#
# 			$("#fcltyName").text(fcltyNm+" 예약 현황");
# 			$("#statusUl").hide();
# 			$("#allReservName").attr("href", "");
# 			$("#timeReservName").attr("href", "");
# 			$("#onceReservName").attr("href", "BD_insertChilCareResveForm.do?q_fclty=1003&q_fcltyId="+fcltyId+"&q_resveStleCode=1003");
#
# 			$(".popup_wrap > div").hide();
# 			$(".tab_popup02").show();
# 			resveOnce();
# 			var el = $("#btnPopup_"+index);
# 			var target = $(".state_p");
# 			target.show();
# 			el.attr("data-focus","on_popup_"+index);
# 			$("#mask").show();
# 			target.attr("tabindex","0");
# 			target.focus();
# 			return false;
# 		};
#
# 		var incPageId = '';
# 		var resve = '';
#
# 		// 상시돌봄 달력
# 		var resveOrdtm = function(month){
# 			$("#q_resveStleCode").val("1002");
# 			URL = "/icare/user/fcltyInfoManage/INC_selectFcltyResveOrdtm.do";
# 			incPageId = "tab_popup01";
# 			resve = "ordtm";
# 			jsCalTimePageLoad(URL, incPageId, month, resve);
# 		};
#
# 		//일시돌봄 달력
# 		var resveOnce = function(month){
# 			$("#q_resveStleCode").val("1003");
# 			URL = "/icare/user/fcltyInfoManage/INC_selectFcltyResveOnce.do";
# 			incPageId = "tab_popup02";
# 			resve = "once";
# 			jsCalTimePageLoad(URL, incPageId, month, resve);
# 		};
#
# 		//달력이나 시간 페이지 불러오기
# 		var jsCalTimePageLoad = function(url, incPageId, way) {
# 			var params = $("#dataForm").serialize();
# 			$.ajaxSetup({cache:false});
# 			$("#" + incPageId).load(url, params, function(result) {
# 			    if(way != null){
# 					var el;
# 					if(resve == "ordtm"){
# 						if(way == "prev"){
# 							el = $("#ordtmPrevMonth");
# 						}else if(way == "next"){
# 							el = $("#ordtmNextMonth");
# 						}
# 					}else if(resve == "once"){
# 						if(way == "prev"){
# 							el = $("#oncePrevMonth");
# 						}else if(way == "next"){
# 							el = $("#onceNextMonth");
# 						}
# 					}
# 					el.attr("data-focus","on_click");
# 					el.focus();
# 				}
# 			});
# 		};
#
# 		function mapSetting(chk){
#
# 			removeAllMarker();
#
# 			$.ajax({
# 				url : "/icare/user/careResve/INC_selectFcltyResveMap.do",
# 				method : "POST",
# 				data : {
# 					atdrcCode : chk,
# 				},
# 				dataType : "json",
# 				async : false,
# 				success : function(response) {
# 					var cnt = response.length;
#
# 					for(var i = 0; i < cnt; i++){
# 						drawMarker(response[i].yCrdntValue, response[i].xCrdntValue, response[i].fcltyNm, 'pin_1.png')
# 					}
# 				},
# 				error : function(response) {
# 					opSysErrorMsg(response.responseText);
# 					return;
# 				}
# 			});
#
# 			if(chk == 11680){							//강남구
# 				map.setView([37.49457,127.06431], 8);
# 			}else if(chk == 11740){						//강동구
# 				map.setView([37.54878,127.14716], 8);
# 			}else if(chk == 11305){						//강북구
# 				map.setView([37.64738,127.00412], 8);
# 			}else if(chk == 11500){						//강서구
# 				map.setView([37.56595,126.81833], 8);
# 			}else if(chk == 11620){						//관악구
# 				map.setView([37.46486,126.95058], 8);
# 			}else if(chk == 11215){						//광진구
# 				map.setView([37.54865,127.08957], 8);
# 			}else if(chk == 11530){						//구로구
# 				map.setView([37.49584,126.85378], 8);
# 			}else if(chk == 11545){						//금천구
# 				map.setView([37.46059,126.90004], 8);
# 			}else if(chk == 11350){						//노원구
# 				map.setView([37.65392,127.07371], 8);
# 			}else if(chk == 11320){						//도봉구
# 				map.setView([37.66639,127.03264], 8);
# 			}else if(chk == 11230){						//동대문구
# 				map.setView([37.58384,127.05182], 8);
# 			}else if(chk == 11590){						//동작구
# 				map.setView([37.49638,126.94797], 8);
# 			}else if(chk == 11440){						//마포구
# 				map.setView([37.56206,126.89807], 8);
# 			}else if(chk == 11410){						//서대문구
# 				map.setView([37.58193,126.93282], 8);
# 			}else if(chk == 11650){						//서초구
# 				map.setView([37.47627,127.01394], 8);
# 			}else if(chk == 11200){						//성동구
# 				map.setView([37.55195,127.04232], 8);
# 			}else if(chk == 11290){						//성북구
# 				map.setView([37.60645,127.0275], 8);
# 			}else if(chk == 11710){						//송파구
# 				map.setView([37.50496,127.10575], 8);
# 			}else if(chk == 11470){						//양천구
# 				map.setView([37.52696,126.86201], 8);
# 			}else if(chk == 11560){						//영등포구
# 				map.setView([37.52174,126.91456], 8);
# 			}else if(chk == 11170){						//용산구
# 				map.setView([37.53231,126.98087], 8);
# 			}else if(chk == 11380){						//은평구
# 				map.setView([37.61718,126.92651], 8);
# 			}else if(chk == 11110){						//종로구
# 				map.setView([37.59907,126.96673], 8);
# 			}else if(chk == 11140){						//중구
# 				map.setView([37.55802,126.99296], 8);
# 			}else if(chk == 11260){						//중랑구
# 				map.setView([37.59468,127.09343], 8);
# 			}else{										//서울특별시
# 				map.setView([37.56412,126.93939], 5);
# 			}
#
# 		};
#
# 		// 지도 자치구 라디오 버튼
# 		var mapCheck = function(chk){
# 			$("#p_area_all").prop("checked", false);
# 			$("#q_map_atdrcCode").val(chk);
# 			mapSetting(chk);
# 		};
#
# 		// 지도 자치구 라디오 전체 버튼
# 		var mapCheckAll = function(chk){
# 			$("#p_area_all").prop("checked", true);
# 			$("#q_map_atdrcCode").val('');
# 			mapSetting(chk);
# 		};
#
# 		function LPAD(s, c, n) {
# 			if (! s || ! c || s.length >= n) {
# 				return s;
# 			}
# 			var max = (n - s.length)/c.length;
# 			for (var i = 0; i < max; i++) {
# 				s = c + s;
# 			}
# 			return s;
# 		};
#
# 		function searchVal(){
# 			$("#q_currPage").val(1);
# 			$("#searchForm").submit();
# 		};
#
# 		function jsMovePage(page){
# 			$("#q_currPage").val(page);
# 			$("#searchForm").submit();
# 		};
#
# 		// 예약 페이지 이동
# 		var calResveDev = function(slteCd, reqstSttus){
# 		    if(reqstSttus == '1006') {
# 		        alert("접수가 마감되었습니다.");
# 		        return false;
# 		    }
# 			var fcltyId = $("#q_fcltyId").val();
# 			location.href="../careResve/BD_insertChilCareResveForm.do?q_fclty=1001&q_fcltyId="+fcltyId+"&q_resveStleCode="+slteCd+"&q_reqstSttusCode="+reqstSttus;
# 		}
#
# 		//]]>
# 	</script>
#
#
#
# <script type="text/javascript">
#     var anlzSessionId = "174247F36BCA226A0AFC75967EF418D3.tomcat2";
#     var anlzClientIp = "35.201.138.116";
#     var anlzMenuCode = "dolbomRESVE_2";
# </script>
# <script type="text/javascript" src="/icare/resources/openworks4/js/analyze/tracker.js"></script>
#
#
#
# <style type="text/css">.fancybox-margin{margin-right:15px;}</style><link rel="stylesheet" type="text/css" media="all" href="//www.seoul.go.kr/seoulgnb/seoul-common-gnb.css"></head>
# <body>
#
#
#
# 	<div id="skipNav">
# 		<p><a href="#container">본문바로가기</a></p>
# 		<p><a href="#gnb">주메뉴바로가기</a></p>
# 	</div>
#
# 	<div id="mask"></div>
#
# 	<div id="seoul-common-gnb">	<div id="seoul-gnb-plugin">		<div class="seoul-gnb-holder">			<p class="seoul-gnb-link"><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=logo&amp;link=https://www.seoul.go.kr" target="_blank" title="새창열림" class="seoul-gnb-icon-link wise-link" data-kind="logo">서울특별시</a></p>			<dl class="seoul-gnb-news">				<dt><a href="https://www.seoul.go.kr/realmnews/in/list.do" target="_blank" title="새창열림(서울소식)" class="seoul-gnb-icon-notice">서울소식</a></dt>				<dd><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=hotissue&amp;link=https://news.seoul.go.kr/gov/unikor_news#view/322570" target="_blank" title="새창열림">2020년 평화·통일 시민 아이디어 공모전 참가자 모집</a></dd>			</dl>			<dl class="seoul-gnb-menu">				<dt>주요메뉴</dt>				<dd><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=seoulnews&amp;link=https://www.seoul.go.kr/realmnews/in/list.do" target="_blank" title="새창열림" class="seoul-gnb-icon-menu1 wise-link" data-kind="seoulnews">서울소식</a></dd>				<dd><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=eungdapso&amp;link=http://eungdapso.seoul.go.kr" target="_blank" title="새창열림" class="seoul-gnb-icon-menu2 wise-link" data-kind="eungdapso">응답소</a></dd>				<dd><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=opengov&amp;link=http://opengov.seoul.go.kr" target="_blank" title="새창열림" class="seoul-gnb-icon-menu3 wise-link" data-kind="opengov">정보공개</a></dd>				<dd>					<button type="button" class="seoul-gnb-icon-menu4">분야별정보</button>					<div class="seoul-gnb-menu-section" style="display: none;">						<dl>							<dt>분야별정보</dt>							<dd>								<ul>									<li><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=citybuild&amp;link=http://news.seoul.go.kr/citybuild/" target="_blank" title="새창열림" class="wise-link" data-kind="citybuild">주택</a></li>									<li><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=economy&amp;link=http://news.seoul.go.kr/economy/" target="_blank" title="새창열림" class="wise-link" data-kind="economy">경제</a></li>									<li><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=traffic&amp;link=http://news.seoul.go.kr/traffic/" target="_blank" title="새창열림" class="wise-link" data-kind="traffic">교통</a></li>									<li><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=env&amp;link=http://news.seoul.go.kr/env/" target="_blank" title="새창열림" class="wise-link" data-kind="env">환경</a></li>									<li><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=welfare&amp;link=http://news.seoul.go.kr/welfare/" target="_blank" title="새창열림" class="wise-link" data-kind="welfare">복지</a></li>									<li><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=safe&amp;link=http://news.seoul.go.kr/safe/" target="_blank" title="새창열림" class="wise-link" data-kind="safe">안전</a></li>									<li><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=culture&amp;link=http://news.seoul.go.kr/culture/" target="_blank" title="새창열림" class="wise-link" data-kind="culture">문화</a></li>									<li><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=gov&amp;link=http://news.seoul.go.kr/gov/" target="_blank" title="새창열림" class="wise-link" data-kind="gov">행정</a></li>								</ul>							</dd>						</dl>						<p><a href="//www.seoul.go.kr/sgnb/seoulgnblog.do?gid=G210&amp;kind=allservice&amp;link=https://www.seoul.go.kr/service/all.do" target="_blank" title="새창열림" class="wise-link" data-kind="allservice"><span class="seoul-gnb-icon-service"></span> 서비스 전체보기</a></p>						<button type="button"><span class="seoul-gnb-icon-service-close"></span><span class="hd-element">분야별 정보 닫기</span></button>					</div>				</dd>			</dl>		</div>	</div></div>
#
# 	<div class="header">
# 		<div class="header_wrap">
# 			<div class="header_top">
# 				<ul>
# 					<!-- 20200422 sns 추가 -->
# 					<li class="header_sns">
# 						<a href="https://www.youtube.com/channel/UChV3e-MPtIwdEU6Md14Bo3A" class="yt" target="_blank" title="새창열림" onclick="se_click_logging('http://www.youtube.com/seoullive?tr_code=sns',location.href);">유튜브</a>
# 						<a href="https://blog.naver.com/seoulkium" class="bl" target="_blank" title="새창열림" onclick="se_click_logging('http://blog.seoul.go.kr?tr_code=sns',location.href);">블로그</a>
# 						<a href="https://www.instagram.com/seoulkium_official/" class="ins" target="_blank" title="새창열림" onclick="se_click_logging('http://www.instagram.com/seoul_official?tr_code=sns',location.href);">인스타그램</a>
# 					</li>
# 					<!-- 20200422 sns 추가 END-->
#
#
# 						<li class="h_btn">
# 							<a href="/icare/login/BD_loginForm.do">로그인</a>
# 						</li>
# 						<li class="h_btn">
# 							<a href="https://iseoul.seoul.go.kr/portal/login/joinGeneral.do?returnurl=/icare/index.do">회원가입</a>
# 						</li>
#
# 				</ul>
# 			</div><!--header_top END-->
# 			<div id="gnb">
# 				<ul>
# 					<li class="logo">
# 						<a href="/icare/index.do" title="메인으로"><img src="/icare/resources/idolbom/img/common/logo.png" alt="서울케어 우리동네키움포털"></a>
# 					</li>
# 					<li class="m_gnbBtn">
# 						<button type="button" class="m_gnbOpen"><img src="/icare/resources/idolbom/img/common/m_gnb.png" alt="메뉴열기"></button>
# 						<button type="button" class="m_gnbClose"><img src="/icare/resources/idolbom/img/common/m_gnb_close.png" alt="메뉴닫기"></button>
# 					</li>
# 					<li class="gnb_wrap" style="display: none;">
# 						<div class="mobile_login">
# 							<ul>
#
#
# 									<li class="login_btn"><a href="/icare/login/BD_loginForm.do">로그인</a> </li>
# 									<li class="join_btn"><a href="https://iseoul.seoul.go.kr/portal/login/joinGeneral.do?returnurl=/icare/index.do">회원가입</a> </li>
#
# 							</ul>
# 							<!-- 20200422 sns 추가 -->
# 							<ul class="mobile_sns">
# 								<li>
# 									<a href="https://www.youtube.com/channel/UChV3e-MPtIwdEU6Md14Bo3A">
# 										<img src="/icare/resources/idolbom/img/main/y_ico.png" alt="유튜브 아이콘">
# 										<span>우리동네 키움튜브</span>
# 									</a>
# 								</li>
# 								<li>
# 									<a href="https://blog.naver.com/seoulkium">
# 										<img src="/icare/resources/idolbom/img/main/b_ico.png" alt="블로그 아이콘">
# 										<span>우리동네 키움블로그</span>
# 									</a>
# 								</li>
# 								<li>
# 									<a href="https://www.instagram.com/seoulkium_official/">
# 										<img src="/icare/resources/idolbom/img/main/i_ico.png" alt="인스타그램 아이콘">
# 										<span>우리동네키움 인스타</span>
# 									</a>
# 								</li>
# 							</ul>
# 							<!-- 20200422 sns 추가 END-->
# 						</div>
# 						<ul>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									<li>
# 										<a href="/icare/dolbomSVC/dolbomSVC_1.jsp" title="서비스 소개 바로가기" class="pc_menu">서비스 소개</a>
#
#
# 											<a href="#" class="mobile_menu">서비스 소개</a>
# 											<div class="gnb_2dep">
# 												<ul class="gnb_2dep_con">
# 													<li class="gnb_2dep_title">
# 				                                        <p class="g_title">서비스 소개</p>
# 			                                        	<p class="g_text">
#
# 											                                            아이 키우는 걱정없는 도시 서울<br>
# 											                                            촘촘한 「온마을아이돌봄 체계」 구축
#
#
#
#
#
# 			                                        	</p>
# 				                                    </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/dolbomSVC/dolbomSVC_1.jsp" title="서울시 온마을 아이돌봄사업 바로가기">서울시 온마을 아이돌봄사업</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do" title="우리동네키움센터(다함께돌봄) 바로가기">우리동네키움센터(다함께돌봄)</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/fcltyInfoManage/BD_selectLocalCenterContactList.do" title="지역아동센터 바로가기">지역아동센터</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/dolbomSVC/dolbomSVC_4.jsp" title="열린육아방&amp;공동육아나눔터 바로가기">열린육아방&amp;공동육아나눔터</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/dolbomSVC/dolbomSVC_6.jsp" title="아이돌보미 서비스 바로가기">아이돌보미 서비스</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/dolbomSVC/dolbomSVC_7.jsp" title="초등돌봄교실 바로가기">초등돌봄교실</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1013" title="우리동네 보육반장 바로가기">우리동네 보육반장</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="https://www.youth.go.kr/yaca/index.do" target="_blank" title="청소년방과후 아카데미 새창으로 바로가기">청소년방과후 아카데미</a>
# 																	</li>
#
#
#
#
# 												</ul>
# 											</div>
#
# 									</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									<li>
# 										<a href="/icare/dolbomRESVE/dolbomRESVE_1.jsp" title="우리동네키움센터 예약 바로가기" class="pc_menu">우리동네키움센터 예약</a>
#
#
# 											<a href="#" class="mobile_menu">우리동네키움센터 예약</a>
# 											<div class="gnb_2dep">
# 												<ul class="gnb_2dep_con">
# 													<li class="gnb_2dep_title">
# 				                                        <p class="g_title">우리동네키움센터 예약</p>
# 			                                        	<p class="g_text">
#
#
# 											                                            돌봄 서비스 이용을 위한<br>
#                                            						 예약 절차 안내 및 예약 신청 가능
#
#
#
#
# 			                                        	</p>
# 				                                    </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/dolbomRESVE/dolbomRESVE_1.jsp" title="돌봄 서비스 예약 안내 바로가기">돌봄 서비스 예약 안내</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/careResve/BD_selectChilCareResveList.do" title="우리동네키움센터 예약 바로가기">우리동네키움센터 예약</a>
# 																	</li>
#
#
#
#
# 												</ul>
# 											</div>
#
# 									</li>
#
#
#
#
#
#
#
#
#
#
#
#
# 									<li class="gnb_bg_none">
# 										<a href="/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do" title="맞춤형 정보 서비스 바로가기" class="pc_menu">맞춤형 정보 서비스</a>
# 										<a href="/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do" title="맞춤형 정보 서비스 바로가기" class="mobile_menu">맞춤형 정보 서비스</a>
#
# 									</li>
#
#
#
#
#
#
#
#
#
#
#
#
# 									<li class="gnb_bg_none">
# 										<a href="/icare/dolbomMAP/dolbomMAP_1.jsp" title="아이돌봄 지도 서비스 바로가기" class="pc_menu">아이돌봄 지도 서비스</a>
# 										<a href="/icare/dolbomMAP/dolbomMAP_1.jsp" title="아이돌봄 지도 서비스 바로가기" class="mobile_menu">아이돌봄 지도 서비스</a>
#
# 									</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									<li>
# 										<a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1001" title="홍보.자료 바로가기" class="pc_menu">홍보.자료</a>
#
#
# 											<a href="#" class="mobile_menu">홍보.자료</a>
# 											<div class="gnb_2dep">
# 												<ul class="gnb_2dep_con">
# 													<li class="gnb_2dep_title">
# 				                                        <p class="g_title">홍보.자료</p>
# 			                                        	<p class="g_text">
#
#
#
#
# 											                                             우리동네키움센터의 새로운 소식과<br>
#                                            						 돌봄에 필요한 다양한 정보 제공
#
#
# 			                                        	</p>
# 				                                    </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1001" title="공지사항 바로가기">공지사항</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1002" title="홍보방 바로가기">홍보방</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1019" title="동영상 바로가기">동영상</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1003" title="우리동네키움센터 소식 바로가기">우리동네키움센터 소식</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1004" title="갤러리 바로가기">갤러리</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1005" title="우리동네 보육반장 바로가기">우리동네 보육반장</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/pr/pbl/pbl_2.jsp" title="프로젝트기반 배움(PBL) 바로가기">프로젝트기반 배움(PBL)</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/vilageResrce/BD_selectVilageCareResrceList.do" title="마을돌봄자원 바로가기">마을돌봄자원</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1018" title="자료실 바로가기">자료실</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1011" title="자주묻는질문 바로가기">자주묻는질문</a>
# 																	</li>
#
#
#
#
# 												</ul>
# 											</div>
#
# 									</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 									<li>
# 										<a href="/icare/partGroup/partGroup_5.jsp" title="우리키움참여단 바로가기" class="pc_menu">우리키움참여단</a>
#
#
# 											<a href="#" class="mobile_menu">우리키움참여단</a>
# 											<div class="gnb_2dep">
# 												<ul class="gnb_2dep_con">
# 													<li class="gnb_2dep_title">
# 				                                        <p class="g_title">우리키움참여단</p>
# 			                                        	<p class="g_text">
#
#
#
#
#
# 											                                             우리 지역 특성에 맞게 주민이 <br>
#                                             					함께 만들어 가는 시민 참여단
#
# 			                                        	</p>
# 				                                    </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/partGroup/partGroup_5.jsp" title="우리키움참여단 소개 바로가기">우리키움참여단 소개</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/partGroup/BD_partGroupForm.do" title="우리키움참여단 인증 바로가기">우리키움참여단 인증</a>
# 																	</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																<!-- 거점형 키움센터일때 이부분 list가져와서 for문 돌려야될듯! -->
#
#
# 																	<li>
# 																		<a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1010" title="참여단활동소식 바로가기">참여단활동소식</a>
# 																	</li>
#
#
#
#
# 												</ul>
# 											</div>
#
# 									</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 						</ul>
# 					</li><!--gnb_wrap END-->
# 				</ul>
# 				<div class="m_gnb_bg"></div>
# 			</div><!--gnb END-->
# 		</div><!--header_wrap END-->
# 	</div><!--header END-->
#
# 	<div class="location">
# 		<div class="location_wrap">
# 			<ul>
# 				<li class="home">
# 					<a href="/icare/index.do"><img src="/icare/resources/idolbom/img/common/sta_home.png" alt="메인으로"></a>
# 				</li>
# 				<li class="m_location"><!--모바일쪽 로케이션-->
# 					<p>우리동네키움센터 예약</p>
# 				</li>
# 				<li class="location_bar main"><!--pc쪽 로케이션-->
# 					<a class="mainMenu" href="/icare/user/careResve/BD_selectChilCareResveList.do;jsessionid=174247F36BCA226A0AFC75967EF418D3.tomcat2" title="주메뉴 선택, 축소됨">우리동네키움센터 예약</a>
#
# 					<ul>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 								<li><a href="/icare/dolbomSVC/dolbomSVC_1.jsp" title="서비스 소개 바로가기">서비스 소개</a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 								<li class="lb_on"><a href="/icare/dolbomRESVE/dolbomRESVE_1.jsp" title="우리동네키움센터 예약 바로가기">우리동네키움센터 예약</a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 								<li><a href="/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do" title="맞춤형 정보 서비스 바로가기">맞춤형 정보 서비스</a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 								<li><a href="/icare/dolbomMAP/dolbomMAP_1.jsp" title="아이돌봄 지도 서비스 바로가기">아이돌봄 지도 서비스</a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 								<li><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1001" title="홍보.자료 바로가기">홍보.자료</a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 								<li><a href="/icare/partGroup/partGroup_5.jsp" title="우리키움참여단 바로가기">우리키움참여단</a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					</ul>
#
# 				</li>
# 				<li class="location_bar sub"><!--pc쪽 로케이션 2depth-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 							<a class="subMenu" href="/icare/user/careResve/BD_selectChilCareResveList.do" title="하위메뉴 선택, 축소됨">우리동네키움센터 예약</a>
#
#
#
#
# 						<ul>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 										<li><a href="/icare/dolbomRESVE/dolbomRESVE_1.jsp" title="돌봄 서비스 예약 안내 바로가기">돌봄 서비스 예약 안내</a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 										<li class="lb_on"><a href="/icare/user/careResve/BD_selectChilCareResveList.do" title="우리동네키움센터 예약 바로가기">우리동네키움센터 예약</a></li>
#
#
#
# 						</ul>
#
# 				</li>
#
# 			</ul>
# 		</div><!--location_wrap END-->
# 	</div><!--location END-->
#
# 	<div id="container" class="sub_container">
# 		<div class="sub_content">
#
#
#
#
#
# 	<h2 class="sub_title01 mb_55">우리동네키움센터<strong style="font-size: 20px; border: ">(다함께돌봄센터)</strong> 예약</h2>
#
# 	<dl class="info_box on mb_62 on" title="우리동네키움센터 예약 서비스 이용 안내(열림)"><!-- 활성화 class="on" -->
# 		<dt><button type="button" class="btn btn_detail on" title="우리동네키움센터 예약 서비스 이용 안내(열림)"><span class="tit"><img src="/icare/resources/idolbom/img/sub/info_icon.png" alt="i">우리동네키움센터 예약 안내</span><em class="action"></em></button></dt>
# 		<dd>
# 			<h5 class="font_b">&lt;키움센터 예약정보 입력&gt;</h5>
# 			<ul class="list_ty01 mt_12">
# 				<li>우리동네키움센터에 예약하시려면 반드시 자녀 정보를 입력해주셔야 해요. (마이페이지에서 자녀 정보 등록 및 수정이 가능해요.)</li>
# 				<li>우리동네키움센터 예약은 자녀 1명당 최대 3곳의 센터에 예약 신청 가능해요. (예약신청 승인 시 타 센터에 예약신청 내역은 자동 취소돼요.)</li>
# 				<li>우리동네키움센터 정원이 초과될 경우, 예약 대기 인원이 발생할 수 있어요. </li>
# 			</ul>
# 			<h5 class="font_b mt_20">&lt;예약정보 알림톡 발송 안내&gt;</h5>
# 			<ul class="list_ty01 mt_12">
# 				<li>우리동네키움센터를 예약하실 경우 예약현황은 회원가입시 등록한 연락처로 알림톡이 발송드려요.</li>
# 				<li>알림톡을 수신 연락처를 변경하고 싶으시면 [마이페이지 – 회원정보변경] 에서 수정해주세요.</li>
# 			</ul>
# 			<h5 class="font_b mt_20">&lt;돌봄유형별 예약방법&gt;</h5>
# 			<div class="table_ty03 mt_12">
# 				<table>
# 					<caption>돌봄유형별 예약방법(돌봄유형, 돌봄특성, 예약기간, 예약시기)</caption>
# 					<colgroup>
# 						<col style="width: 12.5%">
# 						<col style="width: 12.5%">
# 						<col style="width: 25%" span="3">
# 					</colgroup>
# 					<thead>
# 					<tr>
# 						<th scope="col" colspan="2">돌봄유형</th>
# 						<th scope="col">돌봄 특성</th>
# 						<th scope="col">예악기간</th>
# 						<th scope="col">예약시기</th>
# 					</tr>
# 					</thead>
# 					<tbody>
# 					<tr>
# 						<td rowspan="2">상시 돌봄</td>
# 						<td>종일</td>
# 						<td>센터 전체 운영시간동안 이용</td>
# 						<td rowspan="2">
# 							분기별 접수<br>
# 							(1학기, 여름방학, 2학기, 겨울방학)
# 						</td>
# 						<td>분기 종료 4주전부터 가능</td>
# 					</tr>
# 					<tr>
# 						<td>시간제</td>
# 						<td>원하는 요일/시간대를 선택하여 이용</td>
# 						<td>분기종료 2주전부터 가능</td>
# 					</tr>
# 					<tr>
# 						<td colspan="2">일시 돌봄</td>
# 						<td>학교휴업, 이용자의 긴급사유 발생 시 이용</td>
# 						<td>신청일부터 2주 이내</td>
# 						<td>신청일 당일부터 가능</td>
# 					</tr>
# 					</tbody>
# 				</table>
# 			</div>
# 			<p class="table_info mt_12 point">※ 우리동네키움센터별 운영시간이 모두 다르니 반드시 운영시간을 확인해 주세요.</p>
# 			<p class="table_info point">※ 특정일 내 원하는 시간대에 예약이 불가할 경우, 해당 우리동네키움센터에 문의해 주시기 바랍니다.</p>
# 			<p class="table_info point">※ 우리동네키움센터 정원이 초과될 경우, 대기예약이 가능합니다.</p>
# 		</dd>
# 	</dl>
#
# 	<form name="searchForm" id="searchForm" method="post" action="BD_selectChilCareResveList.do" class="form-horizontal">
# ...
#
# 								<li><input type="radio" name="map_atdrcCode" id="p_area_16" value="11200" onclick="mapCheck(this.value)"><label for="p_area_16">성동구</label></li>
#
# 								<li><input type="radio" name="map_atdrcCode" id="p_area_17" value="11290" onclick="mapCheck(this.value)"><label for="p_area_17">성북구</label></li>
#
# 								<li><input type="radio" name="map_atdrcCode" id="p_area_18" value="11710" onclick="mapCheck(this.value)"><label for="p_area_18">송파구</label></li>
#
# 								<li><input type="radio" name="map_atdrcCode" id="p_area_19" value="11470" onclick="mapCheck(this.value)"><label for="p_area_19">양천구</label></li>
#
# 								<li><input type="radio" name="map_atdrcCode" id="p_area_20" value="11560" onclick="mapCheck(this.value)"><label for="p_area_20">영등포구</label></li>
#
# 								<li><input type="radio" name="map_atdrcCode" id="p_area_21" value="11170" onclick="mapCheck(this.value)"><label for="p_area_21">용산구</label></li>
#
# 								<li><input type="radio" name="map_atdrcCode" id="p_area_22" value="11380" onclick="mapCheck(this.value)"><label for="p_area_22">은평구</label></li>
#
# 								<li><input type="radio" name="map_atdrcCode" id="p_area_23" value="11110" onclick="mapCheck(this.value)"><label for="p_area_23">종로구</label></li>
#
# 								<li><input type="radio" name="map_atdrcCode" id="p_area_24" value="11140" onclick="mapCheck(this.value)"><label for="p_area_24">중구</label></li>
#
# 								<li><input type="radio" name="map_atdrcCode" id="p_area_25" value="11260" onclick="mapCheck(this.value)"><label for="p_area_25">중랑구</label></li>
#
# 						</ul><!--area_chk END-->
# 					</div><!--p_area_chk END-->
# 					<div id="map" style="width: 1152px; height: 475px;"></div>
# 					<a href="#" id="popupMapClose" class="popupClose"><img src="/icare/resources/idolbom/img/sub/popup_close.png" alt="팝업 닫기"> </a>
# 				</div>
# 			</div>
#
# 			<ul>
#
#
# 					<li>
#
# 						<h5 class="bb_title">강남1호점 우리동네키움센터(강남 다함께키움센터(태화))</h5>
# 						<ul class="bb_con">
# 							<li class="bb_t">센터정원</li>
#
# 								<li class="bb_con_p">
# 									<span>상시 돌봄</span>45명
# 								</li>
#
# 							<li class="bb_con_p">
# 								<span>일시 돌봄</span>3명
# 							</li>
# 						</ul><!--bb_con-->
# 						<p class="bb_addr ellipsis">서울특별시 강남구 광평로 185</p>
# 						<ul class="bb_btn">
# 							<li class="btn_ty02">
#
#
#
#
# 								<a href="#" id="btnPopup_0" onclick="resvePopup('0', 'GN191101', 'N', '강남1호점 우리동네키움센터(강남 다함께키움센터(태화))', 'Y', '', '2020');">예약현황</a>
# 							</li>
# 							<li class="cor_btn">
#
#
# 									<a href="BD_selectResveStleForm.do?q_fcltyId=GN191101">예약신청</a>
#
# 							</li>
# 						</ul>
# 					</li>
#
# 					<li>
#
# 						<h5 class="bb_title">강남2호점 우리동네키움센터(강남 다함께키움센터(역삼))</h5>
# 						<ul class="bb_con">
# 							<li class="bb_t">센터정원</li>
#
# 								<li class="bb_con_p">
# 									<span>상시 돌봄</span>20명
# 								</li>
#
# 							<li class="bb_con_p">
# 								<span>일시 돌봄</span>4명
# 							</li>
# 						</ul><!--bb_con-->
# 						<p class="bb_addr ellipsis">서울특별시 강남구 논현로64길 7</p>
# 						<ul class="bb_btn">
# 							<li class="btn_ty02">
#
#
#
#
# 								<a href="#" id="btnPopup_1" onclick="resvePopup('1', 'GN191142', 'N', '강남2호점 우리동네키움센터(강남 다함께키움센터(역삼))', 'Y', '', '2020');">예약현황</a>
# 							</li>
# 							<li class="cor_btn">
#
#
# 									<a href="BD_selectResveStleForm.do?q_fcltyId=GN191142">예약신청</a>
#
# 							</li>
# 						</ul>
# 					</li>
#
# 					<li>
#
# 						<h5 class="bb_title">강남3호점 우리동네키움센터(강남 다함께키움센터(청담))</h5>
# 						<ul class="bb_con">
# 							<li class="bb_t">센터정원</li>
#
# 								<li class="bb_con_p">
# 									<span>상시 돌봄</span>20명
# 								</li>
#
# 							<li class="bb_con_p">
# 								<span>일시 돌봄</span>4명
# 							</li>
# 						</ul><!--bb_con-->
# 						<p class="bb_addr ellipsis">서울특별시 강남구 영동대로131길 26</p>
# 						<ul class="bb_btn">
# 							<li class="btn_ty02">
#
#
#
#
# 								<a href="#" id="btnPopup_2" onclick="resvePopup('2', 'GN200601', 'N', '강남3호점 우리동네키움센터(강남 다함께키움센터(청담))', 'Y', '', '2020');">예약현황</a>
# 							</li>
# 							<li class="cor_btn">
#
#
# 									<a href="BD_selectResveStleForm.do?q_fcltyId=GN200601">예약신청</a>
#
# 							</li>
# 						</ul>
# 					</li>
#
# 					<li>
#
# 						<h5 class="bb_title">강남4호점 우리동네키움센터(미미위 세곡 키움센터)</h5>
# 						<ul class="bb_con">
# 							<li class="bb_t">센터정원</li>
#
# 								<li class="bb_con_p">
# 									<span>상시 돌봄</span>25명
# 								</li>
#
# 							<li class="bb_con_p">
# 								<span>일시 돌봄</span>5명
# 							</li>
# 						</ul><!--bb_con-->
# 						<p class="bb_addr ellipsis">서울특별시 강남구 밤고개로 231</p>
# 						<ul class="bb_btn">
# 							<li class="btn_ty02">
#
#
#
#
# 								<a href="#" id="btnPopup_3" onclick="resvePopup('3', 'GN200701', 'N', '강남4호점 우리동네키움센터(미미위 세곡 키움센터)', 'Y', '', '2020');">예약현황</a>
# 							</li>
# 							<li class="cor_btn">
#
#
# 									<a href="BD_selectResveStleForm.do?q_fcltyId=GN200701">예약신청</a>
#
# 							</li>
# 						</ul>
# 					</li>
#
# 					<li>
#
# 						<h5 class="bb_title">강동1호점 우리동네키움센터(상상나루來키움센터)</h5>
# 						<ul class="bb_con">
# 							<li class="bb_t">센터정원</li>
#
# 								<li class="bb_con_p">
# 									<span>상시 돌봄</span>20명
# 								</li>
#
# 							<li class="bb_con_p">
# 								<span>일시 돌봄</span>4명
# 							</li>
# 						</ul><!--bb_con-->
# 						<p class="bb_addr ellipsis">서울특별시 강동구 올림픽로98가길 28</p>
# 						<ul class="bb_btn">
# 							<li class="btn_ty02">
#
#
#
#
# 								<a href="#" id="btnPopup_4" onclick="resvePopup('4', 'GD191101', 'N', '강동1호점 우리동네키움센터(상상나루來키움센터)', 'Y', '', '2020');">예약현황</a>
# 							</li>
# 							<li class="cor_btn">
#
#
# 									<a href="BD_selectResveStleForm.do?q_fcltyId=GD191101">예약신청</a>
#
# 							</li>
# 						</ul>
# 					</li>
#
# 					<li>
#
# 						<h5 class="bb_title">강서1호점 우리동네키움센터(염창동)</h5>
# 						<ul class="bb_con">
# 							<li class="bb_t">센터정원</li>
#
# 								<li class="bb_con_p">
# 									<span>상시 돌봄</span>25명
# 								</li>
#
# 							<li class="bb_con_p">
# 								<span>일시 돌봄</span>5명
# 							</li>
# 						</ul><!--bb_con-->
# 						<p class="bb_addr ellipsis">서울특별시 강서구 양천로67길 93-22</p>
# 						<ul class="bb_btn">
# 							<li class="btn_ty02">
#
#
#
#
# 								<a href="#" id="btnPopup_5" onclick="resvePopup('5', 'GS200203', 'N', '강서1호점 우리동네키움센터(염창동)', 'Y', '', '2020');">예약현황</a>
# 							</li>
# 							<li class="cor_btn">
#
#
# 									<a href="BD_selectResveStleForm.do?q_fcltyId=GS200203">예약신청</a>
#
# 							</li>
# 						</ul>
# 					</li>
#
# 					<li>
#
# 						<h5 class="bb_title">강서2호점 우리동네키움센터(방화3동)</h5>
# 						<ul class="bb_con">
# 							<li class="bb_t">센터정원</li>
#
# 								<li class="bb_con_p">
# 									<span>상시 돌봄</span>20명
# 								</li>
#
# 							<li class="bb_con_p">
# 								<span>일시 돌봄</span>0명
# 							</li>
# 						</ul><!--bb_con-->
# 						<p class="bb_addr ellipsis">서울특별시 강서구 금낭화로 162</p>
# 						<ul class="bb_btn">
# 							<li class="btn_ty02">
#
#
#
#
# 								<a href="#" id="btnPopup_6" onclick="resvePopup('6', 'GS200202', 'N', '강서2호점 우리동네키움센터(방화3동)', 'Y', '', '2020');">예약현황</a>
# 							</li>
# 							<li class="cor_btn">
#
#
# 									<a href="BD_selectResveStleForm.do?q_fcltyId=GS200202">예약신청</a>
#
# 							</li>
# 						</ul>
# 					</li>
#
# 					<li>
#
# 						<h5 class="bb_title">광진1호점 우리동네키움센터</h5>
# 						<ul class="bb_con">
# 							<li class="bb_t">센터정원</li>
#
# 								<li class="bb_con_p">
# 									<span>상시 돌봄</span>20명
# 								</li>
#
# 							<li class="bb_con_p">
# 								<span>일시 돌봄</span>4명
# 							</li>
# 						</ul><!--bb_con-->
# 						<p class="bb_addr ellipsis">서울특별시 광진구 자양번영로 35</p>
# 						<ul class="bb_btn">
# 							<li class="btn_ty02">
#
#
#
#
# 								<a href="#" id="btnPopup_7" onclick="resvePopup('7', 'GJ191101', 'N', '광진1호점 우리동네키움센터', 'Y', '', '2020');">예약현황</a>
# 							</li>
# 							<li class="cor_btn">
#
#
# 									<a href="BD_selectResveStleForm.do?q_fcltyId=GJ191101">예약신청</a>
#
# 							</li>
# 						</ul>
# 					</li>
#
# 			</ul>
# 		</div><!--board_box_ty01 END-->
#
# 		<p class="note_txt">
# 			<img src="/icare/resources/idolbom/img/sub/icon.png" alt="!">우리동네키움센터 이용 현황은 시간대별 예약 인원에 따라 이용 인원이 정원보다 많을 수 있어요!
# 		</p>
#
#
#
#
#
#
#     <div class="paging mt_40">
#         <ul>
#
#
#
#
#
#                             <li class="paging_num paging_num_on">
#                                 <a href="#" title="현재 1 페이지" onclick="return false;">1</a>
#                             </li>
#
#
#
#
#
#                             <li class="paging_num"><a href="#" onclick="jsMovePage(2); return false;" title="2 페이지">2</a></li>
#
#
#
#
#                             <li class="paging_num"><a href="#" onclick="jsMovePage(3); return false;" title="3 페이지">3</a></li>
#
#
#
#
#                             <li class="paging_num"><a href="#" onclick="jsMovePage(4); return false;" title="4 페이지">4</a></li>
#
#
#
#
#                             <li class="paging_num"><a href="#" onclick="jsMovePage(5); return false;" title="5 페이지">5</a></li>
#
#
#
#
#                             <li class="paging_num"><a href="#" onclick="jsMovePage(6); return false;" title="6 페이지">6</a></li>
#
#
#
#
#                             <li class="paging_num"><a href="#" onclick="jsMovePage(7); return false;" title="7 페이지">7</a></li>
#
#
#
#
#                             <li class="paging_num"><a href="#" onclick="jsMovePage(8); return false;" title="8 페이지">8</a></li>
#
#
#
#
#                             <li class="paging_num"><a href="#" onclick="jsMovePage(9); return false;" title="9 페이지">9</a></li>
#
#
#
#
#                             <li class="paging_num"><a href="#" onclick="jsMovePage(10); return false;" title="10 페이지">10</a></li>
#
#
#
#                         <li class="next_btn"><a href="#" onclick="jsMovePage(11); return false;" title="다음페이지그룹 가기"><img src="/icare/resources/idolbom/img/sub/next_btn.png" alt="다음"></a></li>
#                         <li><a href="#" onclick="jsMovePage(12); return false;" title="마지막페이지로 가기"><img src="/icare/resources/idolbom/img/sub/last_btn.png" alt="마지막으로"></a></li>
#
#
#
#
#         </ul>
#     </div>
#
# 	</form>
#
# 	<!--팝업-->
# 	<form id="dataForm" name="dataForm" method="post">
# 		<input type="hidden" name="q_fcltyId" id="q_fcltyId" value="">
# 		<input type="hidden" name="q_year" id="q_year" value="2020">
# 		<input type="hidden" name="q_month" id="q_month" value="10">
# 		<input type="hidden" name="operYear" id="operYear" value="2020">
# 		<input type="hidden" name="q_operYear" id="q_operYear" value="">
# 		<input type="hidden" name="q_satOperAt" id="q_satOperAt" value="">
# 		<input type="hidden" name="q_resveDe" id="q_resveDe" value="">
# 		<input type="hidden" name="q_resveStleCode" id="q_resveStleCode" value="">
# 		<input type="hidden" name="index" class="index" value="">
# 		<input type="hidden" name="buttonHidden" id="buttonHidden" value="N">
# 	</form>
# 	<div style="height: 100%; overflow-y:scroll; ">
# 		<div class="reserv_popup state_p">
# 			<div class="popup_wrap">
# 				<h3 id="fcltyName">예약 현황</h3>
# 				<ul id="statusUl" class="tab">
# 					<li class="tab_on tab_btn01"><a href="#" onclick="resveOrdtm();">상시 돌봄(종일, 시간제)</a> </li>
# 					<li class="tab_btn02"><a href="#" onclick="resveOnce();">일시 돌봄</a> </li>
# 				</ul>
#
# 				<div id="tab_popup01" class="tab_popup01 state_popup" style="position: relative;">
# 				</div><!--tab_popup01 END-->
#
# 				<div id="tab_popup02" class="tab_popup02 state_popup">
# 				</div><!--tab_popup02 END-->
#
# 				<a href="#" class="popupClose"><img src="/icare/resources/idolbom/img/sub/popup_close.png" alt="팝업 닫기"> </a>
# 			</div>
# 		</div><!--팝업 END-->
# 	</div>
#
#
#
#
# 		</div><!--sub_cotnent END-->
# 	</div><!--container END-->
#
# 	<!-- Footer -->
# 	<footer id="footer">
# 		<div class="footer_wrap">
# 			<div class="inner">
# 				<div class="footer-link">
# 					<ul>
# 						<li class="policy"><a href="/icare/privacyAgree.jsp">개인정보처리방침</a></li>
# 						<li class="policy"><a href="/icare/termsAgree.jsp">이용약관</a></li>
# 						<li class="policy"><a href="/icare/siteMap.jsp">사이트맵</a></li>
# 						<li class="policy"><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1012">오류신고</a></li>
# 					</ul>
# 					<div class="sns sns-new">
# 						<!-- RSS연동 완료 후 주석제거 -->
# <!-- 						<a href="#" class="rss">RSS</a> -->
# <!--						<a href="https://www.facebook.com/seoul.kr" class="fb" target="_blank" title="새창열림" onclick="se_click_logging('https://www.facebook.com/seoul.kr?tr_code=sns',location.href);">페이스북</a>
# 						<a href="http://twitter.com/seoulmania" class="tw" target="_blank" title="새창열림" onclick="se_click_logging('http://twitter.com/seoulmania?tr_code=sns',location.href);">트위터</a>
# 						<a href="http://www.instagram.com/seoul_official" class="ins" target="_blank" title="새창열림" onclick="se_click_logging('http://www.instagram.com/seoul_official?tr_code=sns',location.href);">인스타그램</a>
# 						<a href="http://story.kakao.com/ch/seoul" class="ks" target="_blank" title="새창열림" onclick="se_click_logging('http://story.kakao.com/ch/seoul?tr_code=sns',location.href);">카카오스토리</a>
# 						<a href="http://www.youtube.com/seoullive" class="yt" target="_blank" title="새창열림" onclick="se_click_logging('http://www.youtube.com/seoullive?tr_code=sns',location.href);">유튜브</a>
# 						<a href="http://blog.seoul.go.kr" class="bl" target="_blank" title="새창열림" onclick="se_click_logging('http://blog.seoul.go.kr?tr_code=sns',location.href);">블로그</a> -->
# 					</div>
# 				</div>
# 			</div>
# 		</div><!--footer_wrap END-->
# 		<div class="footer_wrap02">
# 			<div class="row">
# 				<div class="inner">
# 					<span class="foo-logo inquiry"><em class="blind">문의 전화번호 120, 정보를 못찾으셨나요? 120 다산콜센터로 물어보세요!</em></span>
# 					<div class="address">
# 						<p class="city">서울특별시청  04524 서울특별시 중구 세종대로 110
# 						</p><p class="">대표전화 : 02-120 또는 02-731-2120</p>
# 						<p class="copy">ⓒ Seoul Metropolitan Government all rights reserved</p>
# 					</div>
# 					<div class="mark">
# 						<!--
# 						<a href="/seoul/gcs.do"  onclick="action_logging({tr_code:'gcs'});" target="_blank" title="굿콘텐츠제공서비스 품질인증서"><img src="/res_newseoul/images/footer_mark_good.png" alt="이용자가 선택한 우수 콘텐츠 서비스 - 한국데이터베이스진흥원 인증마크" /></a>
# 						<a href="#" onclick="action_logging({tr_code:'wa'});" title="웹접근성 품질마크"><img src="/icare/resources/idolbom/img/common/footer_mark_wah.png" alt="과학기술정보통신부 WEB ACCESSIBILITY 마크(웹 접근성 품질인증 마크)"></a>
# 						-->
# 						<a href="http://www.webwatch.or.kr/Situation/WA_Situation.html?MenuCD=110" title="새창으로 열림" target="_blank" rel="noopener">
# 							<img src="/icare/resources/idolbom/img/footer/wa.jpg" border="0" alt="과학기술정보통신부 WEB ACCESSIBILITY 마크(웹 접근성 품질인증 마크)" title="국가 공인 인증기관 : 웹와치">
# 						</a>
# 					</div>
# 				</div>
# 			</div>
# 		</div><!--footer_wrap02 END-->
# 	</footer>
#
# 	<script type="text/javascript" src="//weblog.eseoul.go.kr/wlo/js/install.js"></script>
#
#
#
# </body></html>

# %%
driver = webdriver.Chrome('chromedriver',options=options)
driver.get('https://icare.seoul.go.kr/icare/user/careResve/BD_selectChilCareResveList.do')

# %%
# 크롤링에 사용할 함수 구현

genre_dic = {}

def makeUrl(dateList,i, kinds):
  if kinds == 'playstore': 
    url = 'https://www.mobileindex.com/app/get_rank_all?rt=r&mk=2&c=kr&t=app&rs=100&d=' + dateList[i]
  else:
    url = 'https://www.mobileindex.com/app/get_rank_all?rt=r&mk=1&c=kr&t=app&rs=100&d=' + dateList[i]
  return url

def getGenreUrl(url):
  driver = webdriver.Chrome('chromedriver',options=options)
  driver.get(url)

  html = driver.page_source
  soup = BeautifulSoup(html, 'html.parser')
  genreURL = soup.select('div.item-info > a')
  return genreURL

def get_genre(url,appname):
  if appname in genre_dic:
    return genre_dic[appname]
  dr = webdriver.Chrome('chromedriver',options=options)
  dr.get(url)
  ht = dr.page_source
  so = BeautifulSoup(ht, 'html.parser')
  genre = so.select('tr.text-center')[0].text
  index1 = genre.find('\n',1)
  if genre[index1+1] == '\n':
    genre_dic[appname] = '기타'
    return '기타'
  index2 = genre.find('\n',14)
  genre_dic[appname] = genre[(index1+1):index2]
  return genre[(index1+1):index2]
  
def separateAppRank(rank):
  free_rank = []
  pay_rank = []
  sales_rank = [] 
  for j in range(len(rank)):
    if len(rank[j]) == 100:
      free_rank.append(rank[j][0::2])
    elif len(rank[j]) == 150 or len(rank[j]) == 300:
      free_rank.append(rank[j][0::3])
  return free_rank

def getAppRank(url, year):
  driver = webdriver.Chrome('chromedriver',options=options)
  driver.get(url)

  html = driver.page_source
  soup = BeautifulSoup(html, 'html.parser')
  notices = soup.select('span.appname')
  
  tmp = []
  for n in notices:
    tmp.append(n.text.strip())
  return tmp

# %%
# 크롤링에 사용할 함수 구현

genre_dic = {}

def makeUrl(dateList,i, kinds):
  if kinds == 'playstore': 
    url = 'https://www.mobileindex.com/app/get_rank_all?rt=r&mk=2&c=kr&t=app&rs=100&d=' + dateList[i]
  else:
    url = 'https://www.mobileindex.com/app/get_rank_all?rt=r&mk=1&c=kr&t=app&rs=100&d=' + dateList[i]
  return url

def getGenreUrl(url):
  driver = webdriver.Chrome('chromedriver',options=options)
  driver.get(url)

  html = driver.page_source
  soup = BeautifulSoup(html, 'html.parser')
  genreURL = soup.select('div.item-info > a')
  return genreURL

def get_genre(url,appname):
  if appname in genre_dic:
    return genre_dic[appname]
  dr = webdriver.Chrome('chromedriver',options=options)
  dr.get(url)
  ht = dr.page_source
  so = BeautifulSoup(ht, 'html.parser')
  genre = so.select('tr.text-center')[0].text
  index1 = genre.find('\n',1)
  if genre[index1+1] == '\n':
    genre_dic[appname] = '기타'
    return '기타'
  index2 = genre.find('\n',14)
  genre_dic[appname] = genre[(index1+1):index2]
  return genre[(index1+1):index2]
  
def separateAppRank(rank):
  free_rank = []
  pay_rank = []
  sales_rank = [] 
  for j in range(len(rank)):
    if len(rank[j]) == 100:
      free_rank.append(rank[j][0::2])
    elif len(rank[j]) == 150 or len(rank[j]) == 300:
      free_rank.append(rank[j][0::3])
  return free_rank

def getAppRank(url, year):
  driver = webdriver.Chrome('chromedriver',options=options)
  driver.get(url)

  html = driver.page_source
  soup = BeautifulSoup(html, 'html.parser')
  notices = soup.select('span.appname')
  
  tmp = []
  for n in notices:
    tmp.append(n.text.strip())
  return tmp

# %%
# 크롤링

from tqdm import tqdm
#2019
appRank_p = []
appRank_a = []
date_2019 = ['2019-01-31','2019-02-28','2019-03-31','2019-04-30','2019-05-31','2019-06-30','2019-07-31','2019-08-31','2019-09-30','2019-10-31','2019-11-30','2019-12-31']

date_size = len(date_2019)
kinds = ['playstore']


for kind in kinds:
  appRank = []
  appGenre = []
  for i in tqdm(range(date_size)):
    url = makeUrl(date_2019,i,kind)
    tmp = getAppRank(url,2019)
    appRank.append(tmp)
    genreURL = getGenreUrl(url)
    genreList = []
    for j in range(len(genreURL)):
      genreList.append(get_genre('https://www.mobileindex.com/'+genreURL[j]['href'],tmp[j]))
    appGenre.append(genreList)
    print(kind,' data of ',date_2019[i],' is done')
  if kind == 'playstore': 
    appRank_p = appRank[:]

  p_appRank_free_2019 = separateAppRank(appRank)
  print('p_appRank is done')
  p_appGenre_free_2019 = separateAppRank(appGenre)
  print('p_appGenre is done') 



#2020
appRank = []
date_2020 = ['2020-01-31','2020-02-29','2020-03-31','2020-04-30','2020-05-31','2020-06-30','2020-07-31','2020-08-31', '2020-09-23']
date_size = len(date_2020)
kinds = ['playstore']

for kind in kinds:
  appRank = []
  appGenre = []
  for i in tqdm(range(date_size)):
    url = makeUrl(date_2020,i,kind)
    tmp = getAppRank(url,2020)
    appRank.append(tmp)
    genreURL = getGenreUrl(url)
    genreList = []
    for j in range(len(genreURL)):
      genreList.append(get_genre('https://www.mobileindex.com/'+genreURL[j]['href'],tmp[j]))
    appGenre.append(genreList)
    print(kind,' date of ',date_2020[i],' is done')
  
  p_appRank_free_2020 = separateAppRank(appRank)
  print('p_appRank is done')
  p_appGenre_free_2020  = separateAppRank(appGenre)
  print('p_appGenre is done')
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
#
#   8%|▊         | 1/12 [07:30<1:22:40, 450.96s/it]
# playstore  data of  2019-01-31  is done
#  17%|█▋        | 2/12 [09:47<59:26, 356.64s/it]
# playstore  data of  2019-02-28  is done
#  25%|██▌       | 3/12 [11:53<43:06, 287.34s/it]
# playstore  data of  2019-03-31  is done
#  33%|███▎      | 4/12 [13:31<30:45, 230.69s/it]
# playstore  data of  2019-04-30  is done
#  42%|████▏     | 5/12 [14:23<20:39, 177.12s/it]
# playstore  data of  2019-05-31  is done
#  50%|█████     | 6/12 [16:08<15:32, 155.47s/it]
# playstore  data of  2019-06-30  is done
#  58%|█████▊    | 7/12 [21:26<17:00, 204.02s/it]
# playstore  data of  2019-07-31  is done
#  67%|██████▋   | 8/12 [23:52<12:26, 186.64s/it]
# playstore  data of  2019-08-31  is done
#  75%|███████▌  | 9/12 [25:16<07:48, 156.08s/it]
# playstore  data of  2019-09-30  is done
#  83%|████████▎ | 10/12 [26:55<04:37, 138.97s/it]
# playstore  data of  2019-10-31  is done
#  92%|█████████▏| 11/12 [28:18<02:02, 122.08s/it]
# playstore  data of  2019-11-30  is done
# 100%|██████████| 12/12 [29:35<00:00, 147.97s/it]
#
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# playstore  data of  2019-12-31  is done
# p_appRank is done
# p_appGenre is done
#  11%|█         | 1/9 [01:31<12:14, 91.83s/it]
# playstore  date of  2020-01-31  is done
#  22%|██▏       | 2/9 [04:00<12:42, 109.00s/it]
# playstore  date of  2020-02-29  is done
#  33%|███▎      | 3/9 [05:41<10:38, 106.35s/it]
# playstore  date of  2020-03-31  is done
#  44%|████▍     | 4/9 [07:10<08:25, 101.16s/it]
# playstore  date of  2020-04-30  is done
#  56%|█████▌    | 5/9 [08:27<06:15, 93.95s/it]
# playstore  date of  2020-05-31  is done
#  67%|██████▋   | 6/9 [09:44<04:26, 88.83s/it]
# playstore  date of  2020-06-30  is done
#  78%|███████▊  | 7/9 [10:43<02:40, 80.03s/it]
# playstore  date of  2020-07-31  is done
#  89%|████████▉ | 8/9 [12:24<01:26, 86.41s/it]
# playstore  date of  2020-08-31  is done
# 100%|██████████| 9/9 [13:47<00:00, 91.91s/it]
# playstore  date of  2020-09-23  is done
# p_appRank is done
# p_appGenre is done

# %%
# 크롤링 -> csv로 변환

p_appRank_free = list()
for i in range(len(p_appRank_free_2019)):
  p_appRank_free.append(p_appRank_free_2019[i])
  p_appRank_free.append(p_appGenre_free_2019[i])

col = []
for i in range(12):
  col.append('19_'+str(i+1))
  col.append('19_'+str(i+1)+'_gen')

appRank_free_playstore_df = pd.DataFrame(p_appRank_free)
appRank_free_playstore_df = appRank_free_playstore_df.T
appRank_free_playstore_df.columns = col
appRank_free_playstore_df.to_csv('/content/gdrive/My Drive/빅콘/app/appRank_free_playstore_2019.csv', encoding='utf-8-sig')

p_appRank_free = list()
for i in tqdm(range(len(p_appRank_free_2020))):
  p_appRank_free.append(p_appRank_free_2020[i])
  p_appRank_free.append(p_appGenre_free_2020[i])

col = []
for i in tqdm(range(9)):
  col.append('20_'+str(i+1))
  col.append('20_'+str(i+1)+'_gen')

appRank_free_playstore_df = pd.DataFrame(p_appRank_free)
appRank_free_playstore_df = appRank_free_playstore_df.T
appRank_free_playstore_df.columns = col
appRank_free_playstore_df.to_csv('/content/gdrive/My Drive/빅콘/app/appRank_free_playstore_2020.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 57896.83it/s]
#
#
# 100%|██████████| 9/9 [00:00<00:00, 64527.75it/s]

# %%
pd.read_csv('/content/gdrive/My Drive/빅콘/app/appRank_free_playstore_2019.csv')
# Out:
#     Unnamed: 0  ...     19_12_gen
# 0            0  ...     여행 및 지역정보
# 1            1  ...        엔터테인먼트
# 2            2  ...            소셜
# 3            3  ...            쇼핑
# 4            4  ...            금융
# 5            5  ...           식음료
# 6            6  ...           식음료
# 7            7  ...       도서/참고자료
# 8            8  ...            쇼핑
# 9            9  ...     여행 및 지역정보
# 10          10  ...        엔터테인먼트
# 11          11  ...        커뮤니케이션
# 12          12  ...        엔터테인먼트
# 13          13  ...      지도/내비게이션
# 14          14  ...            도구
# 15          15  ...  동영상 플레이어/편집기
# 16          16  ...            금융
# 17          17  ...            도구
# 18          18  ...        엔터테인먼트
# 19          19  ...  동영상 플레이어/편집기
# 20          20  ...            금융
# 21          21  ...            쇼핑
# 22          22  ...     여행 및 지역정보
# 23          23  ...            쇼핑
# 24          24  ...            사진
# 25          25  ...            사진
# 26          26  ...  동영상 플레이어/편집기
# 27          27  ...            쇼핑
# 28          28  ...            소셜
# 29          29  ...      지도/내비게이션
# 30          30  ...     여행 및 지역정보
# 31          31  ...            소셜
# 32          32  ...        엔터테인먼트
# 33          33  ...            금융
# 34          34  ...    부동산/홈 인테리어
# 35          35  ...     여행 및 지역정보
# 36          36  ...            사진
# 37          37  ...       도서/참고자료
# 38          38  ...            금융
# 39          39  ...            도구
# 40          40  ...      지도/내비게이션
# 41          41  ...        엔터테인먼트
# 42          42  ...            도구
# 43          43  ...      지도/내비게이션
# 44          44  ...    부동산/홈 인테리어
# 45          45  ...           생산성
# 46          46  ...     여행 및 지역정보
# 47          47  ...        커뮤니케이션
# 48          48  ...          비즈니스
# 49          49  ...            금융
#
# [50 rows x 25 columns]

# %%
pd.read_csv('/content/gdrive/My Drive/빅콘/app/appRank_free_playstore_2020.csv')
# Out:
#     Unnamed: 0  ...      20_9_gen
# 0            0  ...          비즈니스
# 1            1  ...         건강/운동
# 2            2  ...            쇼핑
# 3            3  ...           스포츠
# 4            4  ...           식음료
# 5            5  ...  동영상 플레이어/편집기
# 6            6  ...         맞춤 설정
# 7            7  ...        엔터테인먼트
# 8            8  ...           식음료
# 9            9  ...    부동산/홈 인테리어
# 10          10  ...        커뮤니케이션
# 11          11  ...            금융
# 12          12  ...            금융
# 13          13  ...            도구
# 14          14  ...           식음료
# 15          15  ...            소셜
# 16          16  ...            쇼핑
# 17          17  ...            쇼핑
# 18          18  ...         맞춤 설정
# 19          19  ...       도서/참고자료
# 20          20  ...            쇼핑
# 21          21  ...            도구
# 22          22  ...            도구
# 23          23  ...  동영상 플레이어/편집기
# 24          24  ...            쇼핑
# 25          25  ...            도구
# 26          26  ...           식음료
# 27          27  ...            쇼핑
# 28          28  ...      지도/내비게이션
# 29          29  ...           생산성
# 30          30  ...           생산성
# 31          31  ...           생산성
# 32          32  ...     여행 및 지역정보
# 33          33  ...     여행 및 지역정보
# 34          34  ...      지도/내비게이션
# 35          35  ...            금융
# 36          36  ...            쇼핑
# 37          37  ...            소셜
# 38          38  ...        커뮤니케이션
# 39          39  ...            쇼핑
# 40          40  ...            쇼핑
# 41          41  ...         건강/운동
# 42          42  ...        음악/오디오
# 43          43  ...            금융
# 44          44  ...            쇼핑
# 45          45  ...            금융
# 46          46  ...      지도/내비게이션
# 47          47  ...            소셜
# 48          48  ...        엔터테인먼트
# 49          49  ...            쇼핑
#
# [50 rows x 19 columns]
